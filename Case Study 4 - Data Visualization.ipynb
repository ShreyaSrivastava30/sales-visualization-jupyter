# %%
import os
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
os.chdir('C:\\Users\\SHREYA\\Downloads\\Python Foundation Case Study 4 - Python Visualization Case Study\\Case Study 4 - Python Visualizations Case Study')

# %%
sales = pd.read_csv('SalesData.csv')

# %%
sales
# Out:
#       AccountId  AccountName   Region       Division        City State  Tier  \
# 0          1116     Account1     West    DIAMONDBACK   PHOENIX W    AZ   Low
# 1          1116     Account1     West    DIAMONDBACK   PHOENIX W    AZ   Low
# 2          2391     Account2     East      MINUTEMEN    HARTFORD    CT   Med
# 3          2391     Account2     East      MINUTEMEN    HARTFORD    CT   Med
# 4          2397     Account3     East      MINUTEMEN   WORCESTER    MA   Med
# ...         ...          ...      ...            ...         ...   ...   ...
# 3704       7576  Account2736     East         EMPIRE    SYRACUSE    NY   Out
# 3705       4969  Account2740  Central  SOUTHERN STAR  MONTGOMERY    AL   Med
# 3706       2850  Account2746     East        SYNERGY   ASHEVILLE    NC  High
# 3707    1102265  Account2748     West    DIAMONDBACK  SCOTTSDALE    AZ   Out
# 3708      47282  Account2750     West       CHARGERS    SAN JOSE    CA   Low
#
# ...

# %%
sales.shape
# Out:
# (3709, 14)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3709 entries, 0 to 3708
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   AccountId           3709 non-null   int64
#  1   AccountName         3709 non-null   object
#  2   Region              3709 non-null   object
#  3   Division            3709 non-null   object
#  4   City                3709 non-null   object
#  5   State               3709 non-null   object
#  6   Tier                3709 non-null   object
#  7   Month               3709 non-null   object
#  8   Sales2015           3709 non-null   float64
#  9   Sales2016           3709 non-null   float64
#  10  Units2015           3709 non-null   float64
#  11  Units2016           3709 non-null   float64
#  12  TargetAchevied2015  3709 non-null   float64
#  13  TargetAchevied2016  3709 non-null   float64
# dtypes: float64(6), int64(1), object(7)
# memory usage: 405.8+ KB

# %%
sales.columns
# Out:
# Index(['AccountId', 'AccountName', 'Region', 'Division', 'City', 'State',
#        'Tier', 'Month', 'Sales2015', 'Sales2016', 'Units2015', 'Units2016',
#        'TargetAchevied2015', 'TargetAchevied2016'],
#       dtype='object')

# %%
sales.dtypes
# Out:
# AccountId               int64
# AccountName            object
# Region                 object
# Division               object
# City                   object
# State                  object
# Tier                   object
# Month                  object
# Sales2015             float64
# Sales2016             float64
# Units2015             float64
# Units2016             float64
# TargetAchevied2015    float64
# TargetAchevied2016    float64
# dtype: object

# %%
sales.isna().sum()
# Out:
# AccountId             0
# AccountName           0
# Region                0
# Division              0
# City                  0
# State                 0
# Tier                  0
# Month                 0
# Sales2015             0
# Sales2016             0
# Units2015             0
# Units2016             0
# TargetAchevied2015    0
# TargetAchevied2016    0
# Qtr                   0
# dtype: int64

# %%
# Histogram for Sales2015
plt.figure(figsize=(8, 5))
sns.histplot(sales['Sales2015'], bins=30, kde=True)
plt.title('Histogram of Sales 2015')
plt.xlabel('Sales 2015')
plt.ylabel('Frequency')
plt.show()

# Boxplot for Sales2016
plt.figure(figsize=(8, 5))
sns.boxplot(x=sales['Sales2016'])
plt.title('Boxplot of Sales 2016')
plt.xlabel('Sales 2016')
plt.show()

# Scatterplot between Sales2015 and Units2015
plt.figure(figsize=(8, 5))
sns.scatterplot(x='Units2015', y='Sales2015', data=sales)
plt.title('Scatterplot of Units 2015 vs Sales 2015')
plt.xlabel('Units 2015')
plt.ylabel('Sales 2015')
plt.show()

# %% [markdown]
# '''Histogram of Sales 2015
# Highly right-skewed distribution.
#
# Majority of sales are low values — very few high sales.
#
# There are a few extreme high sales (outliers).
#
#
# Boxplot of Sales 2016
# Data has many outliers (visible as dots).
#
# Sales are concentrated near the lower end.
#
# Spread is large, with high variance.
#
# Negative sales values are present (could be returns or data issues — worth checking!).
#
#
# Scatterplot: Units 2015 vs Sales 2015
# Strong positive correlation — more units sold → higher sales.
#
# Pattern is mostly linear, with a few large sales at high unit values.
#
# Outliers exist but relationship is clear.'''

# %%
## 1. Compare Sales by region for 2016 with 2015 using bar chart.

# %%
sales[['Region','Sales2015','Sales2016']].groupby('Region').sum().plot(kind='bar')
plt.ylabel('Sales')
plt.title('Sales by Region in 2015 & 2016')
plt.show()

# %% [raw]
# We can conclude from above visualization that sales increased in 2016 as compared to 2015 in each and every region. East region shows highest increment in sales.

# %%
## 2. What are the contributing factors to the sales for each region in 2016. Visualize it using a Pie Chart.

# %%
region_2016_sales = sales[['Region','Sales2016']].groupby('Region').sum()

# %%
region_2016_sales
# Out:
#             Sales2016
# Region
# Central  9.787809e+06
# East     1.266723e+07
# West     7.209689e+06

# %%
plt.pie(region_2016_sales.Sales2016,autopct="%1.0f%%",labels=["Central","East","West"],shadow=True,colors=['r', 'g', 'b'])
plt.title("Contributing factors to the sales for each region in 2016")
plt.show()

# %% [raw]
# East region shows maximum contribution in terms of sales in year 2016.

# %%
## 3. Compare the total sales of 2015 and 2016 with respect to Region and Tiers.

# %%
sales[['Tier','Region','Sales2015','Sales2016']].groupby(['Region','Tier']).sum().plot(kind='bar',figsize=(15,8))
plt.ylabel("Sales")
plt.title("Total sales of 2015 and 2016 with respect to Region and Tiers")
plt.show()

# %% [raw]
# East Region and High Tier shows maximum contribution in sales in year 2015 and 2016.

# %%
## 4. In East region, which state registered a decline in 2016 as compared to 2015?

# %%
sales[sales.Region=='East'][['State','Sales2015','Sales2016']].groupby('State').sum().plot(kind='bar',figsize=(15,8))
plt.ylabel("Sales")
plt.title("Total sales of 2015 and 2016 in East Region with respect to State")
plt.show()

# %% [raw]
# NY is the only state that shows decline in 2016 as compared to 2015.

# %%
## 5. In all the High tier, which Division saw a decline in number of units sold in 2016 compared to 2015?

# %%
sales[sales.Tier=='High'][['Division','Units2015','Units2016']].groupby('Division').sum().plot(kind='bar',figsize=(18,8))
plt.ylabel("Units Sold")
plt.title("Total number of units sold in 2015 and 2016 for High Tier with respect to Division")
plt.show()

# %% [raw]
# No division shows a decline in number of units sold in 2016 as compared to 2015.

# %%
## 6. Create a new column Qtr using numpy.where() or any suitable utility in the imported dataset. 
##    The Quarters are based on months and defined as -
##          • Jan - Mar : Q1
##          • Apr - Jun : Q2
##          • Jul - Sep : Q3
##          • Oct - Dec : Q4

# %%
quarter = []
for x in sales.Month :
    if x in ["Jan","Feb","Mar"]:
        quarter.append("Q1")
    elif x in ["Apr","May","Jun"]:
        quarter.append("Q2")
    elif x in ["Jul","Aug","Sep"]:
        quarter.append("Q3")
    else:
        quarter.append("Q4")

# %%
sales['Qtr'] = quarter

# %%
sales
# Out:
#       AccountId  AccountName   Region       Division        City State  Tier  \
# 0          1116     Account1     West    DIAMONDBACK   PHOENIX W    AZ   Low
# 1          1116     Account1     West    DIAMONDBACK   PHOENIX W    AZ   Low
# 2          2391     Account2     East      MINUTEMEN    HARTFORD    CT   Med
# 3          2391     Account2     East      MINUTEMEN    HARTFORD    CT   Med
# 4          2397     Account3     East      MINUTEMEN   WORCESTER    MA   Med
# ...         ...          ...      ...            ...         ...   ...   ...
# 3704       7576  Account2736     East         EMPIRE    SYRACUSE    NY   Out
# 3705       4969  Account2740  Central  SOUTHERN STAR  MONTGOMERY    AL   Med
# 3706       2850  Account2746     East        SYNERGY   ASHEVILLE    NC  High
# 3707    1102265  Account2748     West    DIAMONDBACK  SCOTTSDALE    AZ   Out
# 3708      47282  Account2750     West       CHARGERS    SAN JOSE    CA   Low
#
# ...

# %%
## 7. Compare Qtr wise sales in 2015 and 2016 in a bar plot.

# %%
sales[['Qtr','Sales2015','Sales2016']].groupby('Qtr').sum().plot(kind='bar',figsize=(15,5))
plt.ylabel("Sales")
plt.title("Quarter wise sales in 2015 and 2016")
plt.show()

# %% [raw]
# Q3 shows maximum sales for both 2015 and 2016.

# %%
## 8. Determine the composition of Qtr wise sales in 2016 with regards to all the Tiers in a pie chart.

# %%
q1 = sales[sales.Qtr=='Q1'][['Tier','Sales2016']].groupby('Tier').sum()
q2 = sales[sales.Qtr=='Q2'][['Tier','Sales2016']].groupby('Tier').sum()
q3 = sales[sales.Qtr=='Q3'][['Tier','Sales2016']].groupby('Tier').sum()
q4 = sales[sales.Qtr=='Q4'][['Tier','Sales2016']].groupby('Tier').sum()

# %%
plt.pie(q1.Sales2016,autopct="%1.0f%%",labels=["High","Low","Med","Out"],shadow=True,colors=['pink','grey','indigo','cyan'])
plt.title("Composition of Q1 (sales wise) in 2016 with regards to all the Tiers")
plt.show()

# %%
plt.pie(q2.Sales2016,autopct="%1.0f%%",labels=["High","Low","Med","Out"],shadow=True,colors=['pink','grey','indigo','cyan'])
plt.title("Composition of Q2 (sales wise) in 2016 with regards to all the Tiers")
plt.show()

# %%
plt.pie(q3.Sales2016.head(3),autopct="%1.0f%%",labels=["High","Low","Med"],shadow=True,colors=['pink','grey','indigo'])
plt.title("Composition of Q3 (sales wise) in 2016 with regards to all the Tiers")
plt.show()               ## out was showing negative sales so neglecting it

# %%
plt.pie(q4.Sales2016,autopct="%1.0f%%",labels=["High","Low","Med","Out"],shadow=True,colors=['pink','grey','indigo','cyan'])
plt.title("Composition of Q4 (sales wise) in 2016 with regards to all the Tiers")
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(sales[['Sales2015', 'Sales2016', 'Units2015', 'Units2016']].corr(), 
            annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap of Sales and Units (2015 vs 2016)")
plt.show()

# %% [markdown]
# # Observations from Correlation Heatmap:
#
# - Sales2015 and Units2015 have a high correlation (0.92) — as expected, more units sold results in more revenue.
# - Sales2016 and Units2016 also show a strong positive correlation (0.95).
# - Year-over-year correlations are moderate (~0.6), indicating some consistency but also potential shifts in sales dynamics between 2015 and 2016.
# - This correlation analysis confirms that unit sales significantly drive total revenue.

# %%
# Select numeric columns for pairplot
numeric_cols = ['Sales2015', 'Sales2016', 'Units2015', 'Units2016']

# Create pairplot
sns.pairplot(sales[numeric_cols], height=2.5)
plt.suptitle("Pairplot of Sales and Units (2015 vs 2016)", y=1.02)
plt.show()

# %% [markdown]
# Sales2015 & Units2015
# Strong positive linear relationship — more units sold → higher sales.
# Clear pattern, few outliers.
#
# Sales2016 & Units2016
# Also shows a positive trend, but more spread and noise than 2015.
# Some negative Sales2016 — should be investigated (returns, refunds, or data errors?).
#
# Cross-year comparisons
# Sales2015 vs Sales2016 → some correlation, but more scattered.
# Units2015 vs Units2016 → moderate relationship; product sales patterns may have shifted.
#
# Distributions
# Sales columns are right-skewed with outliers.
# Units columns show a large number of low-unit sales; few products have high unit sales.
#
# Key takeaways:
# Strong expected relationships between units and sales per year.
# Negative Sales2016 — requires attention.
# Sales patterns changed between 2015 & 2016 — consider investigating product/category-level trends.
# Outliers present — especially in Sales.
